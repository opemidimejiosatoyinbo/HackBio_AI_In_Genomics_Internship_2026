# %% [markdown]
# ## HackBio - AI in Genomics
#
# **Stage Zero Task:**
# Write a simple Python script for printing the names, affiliation, and the name of the genes you love most, and the name of the organism bearing the gene. The final output should be something like, “Hi, my name is Adewale Ogunleye, a researcher at the University of Tübingen. My favorite gene is lexA in _Escherichia coli_.”

# %%
# Simple Python Script
# This script prints:
# 1. My full name
# 2. My affiliation
# 3. My favorite gene
# 4. The name of the organism bearing the gene

# MY PERSONAL INFORMATION
name = "Opemidimeji Osatoyinbo" # My full name
affiliation = "Graduate Assistant at the University of Ilorin" # My affiliation (title and institution)
favorite_gene = "mecA" # My favorite gene
organism =" Staphylococcus aureus" # The name of the organism bearing the gene (to be italicized)

# To print the final output:
# Using an f-string for clean, readable formatting
print(f"Hi, my name is {name}, a {affiliation}. "
      f"\nMy favorite gene is {favorite_gene} in \033[3m{organism}\033[0m.")
